# %% [markdown]
# ### Ollama with Langchain

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

# Initialize the model
model = OllamaLLM(model="gemma2:latest")

# Create a prompt template
template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

# Create the chain
chain = prompt | model

# Run it
response = chain.invoke({"question": "What is LangChain?"})
print(response)
# Out:
# Okay, let's break down what LangChain is.  Here's a step-by-step explanation:
#
# 1. **What is it?** LangChain is a framework designed to help developers build applications powered by large language models (LLMs) like me.
#
# 2. **Why was it created?** LLMs are incredibly powerful, but using them effectively in real-world applications can be complex. LangChain simplifies this process by providing tools and building blocks.
#
# 3. **What does it offer?**
#
#    * **Chain Creation:**  It allows you to create "chains" of different components (LLMs, APIs, databases, etc.) that work together to accomplish a specific task.
#    * **Data Management:** LangChain helps integrate LLMs with external data sources, enabling them to access and process information beyond their initial training.
#    * **Agent Capabilities:** It supports the creation of "agents" - LLM-powered entities that can interact with their environment, make decisions, and perform actions.
#
# 4. **Example Use Cases:**
#
#    * **Chatbots:**  Build more sophisticated chatbots that can access information, perform calculations, or even control other applications.
#    * **Text Summarization & Analysis:**  Automate the process of summarizing documents or extracting key insights from large amounts of text.
#    * **Code Generation:**  Use LLMs to assist in writing and debugging code.
#
# 5. **Key Benefits:**
#
#    * **Modularity:** Easily combine different components to create custom applications.
#    * **Efficiency:** Streamlines the development process for LLM-powered applications.
#    * **Scalability:** Designed to handle complex tasks and large datasets.
#
#
#
# Let me know if you have any more questions about LangChain or would like me to elaborate on a specific aspect!

# %% [markdown]
# ### Simple Query

# %%
from langchain_ollama.llms import OllamaLLM

llm = OllamaLLM(
    model="gemma2:latest",
    temperature=0.7
)

response = llm.invoke("What is Apache Spark?")
print(response)
# Out:
# Apache Spark is a powerful open-source **data processing engine** designed for efficient and large-scale data analysis.
#
# Here's a breakdown:
#
# **Key Features:**
#
# * **Fast & Efficient:** Spark excels at processing massive datasets due to its in-memory computing capabilities, distributed architecture, and optimized execution engine.
# * **Versatility:** It supports a wide range of data processing tasks, including:
#     * Batch Processing: Analyzing large datasets stored on disk.
#     * Streaming Processing: Handling real-time data streams for immediate analysis.
#     * Machine Learning: Building and deploying machine learning models at scale.
#     * Graph Processing: Analyzing relationships and connections within complex networks.
# * **Scalability:** Spark can seamlessly distribute workloads across a cluster of machines, allowing it to handle truly massive datasets.
#
# **How it Works:**
#
# Spark utilizes a distributed architecture where data is split into smaller chunks and processed in parallel by multiple worker nodes. It employs a directed acyclic graph (DAG) representation for tasks, optimizing execution and resource utilization.
#
# **Benefits:**
#
# * **High Performance:** In-memory processing and optimized algorithms result in significant speedups compared to traditional disk-based systems.
# * **Ease of Use:** Spark provides a high-level API (Spark SQL, PySpark, etc.) that simplifies data manipulation and analysis.
# * **Community Support:** As an open-source project, Spark boasts a large and active community contributing to its development and providing support.
#
# **Use Cases:**
#
# * **Data Analytics:** Analyzing customer behavior, market trends, website traffic, etc.
# * **Machine Learning:** Building recommendation systems, fraud detection models, image recognition algorithms, and more.
# * **Real-Time Data Processing:** Monitoring system performance, analyzing sensor data, detecting anomalies in streaming feeds.
#
# **Overall, Apache Spark is a versatile and powerful tool for anyone working with large datasets and requiring high-performance data processing capabilities.**

# %% [markdown]
# ### Installing new model in Ollama

# %%
# !ollama pull llava
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏ 773 KB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏ 1.9 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏ 3.7 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏ 4.3 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏ 6.3 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏ 8.4 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏  13 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏  14 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   0% ▕                  ▏  17 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  21 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  24 MB/4.1 GB                  pulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  27 MB/4.1 GB   24 MB/s   2m49spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  30 MB/4.1 GB   24 MB/s   2m49spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  30 MB/4.1 GB   24 MB/s   2m49spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  35 MB/4.1 GB   24 MB/s   2m49spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  38 MB/4.1 GB   24 MB/s   2m49spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  39 MB/4.1 GB   24 MB/s   2m49spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  42 MB/4.1 GB   24 MB/s   2m49spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  45 MB/4.1 GB   24 MB/s   2m48spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  47 MB/4.1 GB   24 MB/s   2m48spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  49 MB/4.1 GB   24 MB/s   2m48spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  52 MB/4.1 GB   25 MB/s   2m40spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  54 MB/4.1 GB   25 MB/s   2m40spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  57 MB/4.1 GB   25 MB/s   2m40spulling manifest
# pulling 170370233dd5:   1% ▕                  ▏  60 MB/4.1 GB   25 MB/s   2m40spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  62 MB/4.1 GB   25 MB/s   2m40spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  65 MB/4.1 GB   25 MB/s   2m39spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  68 MB/4.1 GB   25 MB/s   2m39spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  69 MB/4.1 GB   25 MB/s   2m39spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  73 MB/4.1 GB   25 MB/s   2m39spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  76 MB/4.1 GB   25 MB/s   2m39spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  78 MB/4.1 GB   25 MB/s   2m36spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  81 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  84 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  86 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  88 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  91 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  92 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  95 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏  98 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   2% ▕                  ▏ 100 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 103 MB/4.1 GB   25 MB/s   2m36spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 106 MB/4.1 GB   25 MB/s   2m36spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 107 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 110 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 113 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 115 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 118 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 121 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 122 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 125 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 128 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 129 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 132 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 135 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 137 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 140 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   3% ▕                  ▏ 143 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 144 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 147 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 150 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 151 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 154 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 157 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 159 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 162 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 165 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 166 MB/4.1 GB   25 MB/s   2m35spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 170 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 172 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 174 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 177 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 180 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   4% ▕                  ▏ 181 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 185 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 188 MB/4.1 GB   25 MB/s   2m34spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 190 MB/4.1 GB   25 MB/s   2m33spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 193 MB/4.1 GB   25 MB/s   2m33spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 196 MB/4.1 GB   25 MB/s   2m33spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 198 MB/4.1 GB   25 MB/s   2m33spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 201 MB/4.1 GB   25 MB/s   2m33spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏ 205 MB/4.1 GB   25 MB/s   2m33spulling manifest
# pulling 170370233dd5:   5% ▕                  ▏
ulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 645 MB/4.1 GB   26 MB/s    2m8spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 649 MB/4.1 GB   26 MB/s    2m8spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 650 MB/4.1 GB   26 MB/s    2m8spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 653 MB/4.1 GB   26 MB/s    2m8spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 656 MB/4.1 GB   26 MB/s    2m8spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 659 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 662 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 664 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 666 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 669 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 673 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  16% ▕██                ▏ 675 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  17% ▕██                ▏ 679 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  17% ▕██                ▏ 682 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  17% ▕██                ▏ 684 MB/4.1 GB   26 MB/s    2m7spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 687 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 690 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 692 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 695 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 699 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 700 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 703 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 705 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 708 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 711 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 715 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  17% ▕███               ▏ 717 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 719 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 723 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 725 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 728 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 731 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 732 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 735 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 738 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 740 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 743 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 745 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 747 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 750 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 753 MB/4.1 GB   26 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 754 MB/4.1 GB   27 MB/s    2m4spulling manifest
# pulling 170370233dd5:  18% ▕███               ▏ 757 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 760 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 761 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 764 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 767 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 769 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 772 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 774 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 776 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 779 MB/4.1 GB   27 MB/s    2m3spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 782 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 783 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 786 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 789 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 790 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 793 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 796 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 797 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  19% ▕███               ▏ 800 MB/4.1 GB   27 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 802 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 803 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 805 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 808 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 809 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 812 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 815 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 815 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 818 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 820 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 822 MB/4.1 GB   26 MB/s    2m2spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 824 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 825 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 827 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 829 MB/4.1 GB   26 MB/s    2m6spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 830 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 832 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 834 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 835 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  20% ▕███               ▏ 839 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 842 MB/4.1 GB   26 MB/s    2m5spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 845 MB/4.1 GB   25 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 846 MB/4.1 GB   25 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 848 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 850 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 852 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 855 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 858 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 860 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 863 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 867 MB/4.1 GB   25 MB/s    2m9spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 868 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 869 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 873 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 873 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 876 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 879 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 880 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  21% ▕███               ▏ 883 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 885 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 887 MB/4.1 GB   24 MB/s   2m10spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 890 MB/4.1 GB   24 MB/s   2m13spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 893 MB/4.1 GB   24 MB/s   2m13spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 893 MB/4.1 GB   24 MB/s   2m13spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 897 MB/4.1 GB   24 MB/s   2m12spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 900 MB/4.1 GB   24 MB/s   2m12spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 901 MB/4.1 GB   24 MB/s   2m12spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 904 MB/4.1 GB   24 MB/s   2m12spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 908 MB/4.1 GB   24 MB/s   2m12spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 909 MB/4.1 GB   24 MB/s   2m12spulling manifest
# pulling 170370233dd5:  22% ▕███               ▏ 912 MB/4.1 GB   24 MB/s   2m12spulling manifest
# pulling 170370233dd5:  22% ▕████              ▏ 914 MB/4.1 GB   23 MB/s   2m15spulling manifest
# pulling 170370233dd5:  22% ▕████              ▏ 916 MB/4.1 GB   23 MB/s   2m14spulling manifest
# pulling 170370233dd5:
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 170370233dd5: 100% ▕██████████████████▏ 4.1 GB
# pulling 72d6f08a42f6: 100% ▕██████████████████▏ 624 MB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling c43332387573: 100% ▕██████████████████▏   67 B
# pulling ed11eda7790d: 100% ▕██████████████████▏   30 B
# pulling 7c658f9561e5: 100% ▕██████████████████▏  564 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ### Streaming text

# %%
from langchain_ollama.llms import OllamaLLM

llm = OllamaLLM(model="gemma2:latest")

for chunk in llm.stream("Explain the CAP theorem in distributed systems"):
    print(chunk, end="", flush=True)
# Out:
# The CAP theorem, also known as Brewer's theorem, is a fundamental concept in distributed systems that states you can only choose **two out of three** guarantees:
#
# * **Consistency:** Every read receives the most recent write or an error. This means all nodes see the same data at the same time.
# * **Availability:** Every request receives a (non-error) response, even if some data is inconsistent. This means the system is always operational and responds to requests.
# * **Partition Tolerance:** The system continues to operate despite network partitions, where nodes can't communicate with each other.
#
# **Here's a breakdown:**
#
# * **Consistency:** Imagine a bank account. If you deposit money, everyone should see the updated balance immediately. Consistency ensures this.
#
# * **Availability:** Think of an e-commerce website during a peak sale. Even if some servers are down, customers should still be able to place orders (though they might not see the most up-to-date stock information).
#
# * **Partition Tolerance:** If a natural disaster causes communication failures between servers, a partition-tolerant system will keep functioning, albeit potentially with inconsistencies.
#
# **The Catch:**
#
# You cannot have all three guarantees simultaneously in a distributed system. This is because they often conflict:
#
# * **Consistency and Availability:** Maintaining consistency requires all nodes to agree on the latest data, which can be impossible during partitions. If you prioritize availability, some nodes might continue operating with outdated information.
# * **Availability and Partition Tolerance:** To ensure availability during partitions, some nodes might operate independently, potentially leading to inconsistencies.
#
# **Choosing Your Priorities:**
#
# The CAP theorem helps you make informed decisions about your distributed system's design. Consider:
#
# * **What are the consequences of inconsistency?** If it's critical (e.g., financial transactions), prioritize consistency.
# * **How important is constant availability?** If downtime is unacceptable, prioritize availability.
# * **How likely are partitions to occur?** If they are frequent, prioritize partition tolerance.
#
# Ultimately, there's no one-size-fits-all solution. Understanding the CAP theorem allows you to choose the best trade-offs for your specific needs.

# %% [markdown]
# ### Ollama different Options - without langchain

# %%
import ollama

response = ollama.chat(
    model='gemma2:latest',
    messages=[
        {
            'role': 'user',
            'content': 'Write a short poem about data engineering'
        }
    ],
    options={
        'temperature': 0.8,
        'top_p': 0.9,
    }
)

print(response['message']['content'])
# Out:
# In oceans of data, vast and deep,
# Data engineers their secrets keep.
# With pipelines strong and ETL's might,
# They shape the flow, both day and night.
#
# From raw to refined, a graceful dance,
# Transforming bits into valuable glance.
# Schema designs, a structured art,
# Where knowledge blooms, a beating heart.
#
# BigQuery hums, Spark ignites,
# As insights rise from digital heights.
# Data engineers, unseen yet key,
# Unlock the future, for you and me.

# %% [markdown]
# ### Ollama as Rest API endpoint

# %%
import requests
import json

url = "http://localhost:11434/api/generate"

data = {
    "model": "gemma2:latest",
    "prompt": "Explain the CAP theorem",
    "stream": True
}

response = requests.post(url, json=data, stream=True)

for line in response.iter_lines():
    if line:
        chunk = json.loads(line)
        print(chunk.get('response', ''), end='', flush=True)
# Out:
# The CAP theorem, also known as Brewer's theorem, is a fundamental concept in distributed systems. It states that it is impossible for a distributed data store to simultaneously provide all three of the following guarantees:
#
# * **Consistency (C):**  All nodes see the same data at the same time. This means that any read operation will return the most recent write, regardless of which node it's performed on.
# * **Availability (A):** Every request receives a (non-error) response, even if some nodes are down or unavailable.
#
# * **Partition tolerance (P):** The system continues to operate despite network partitions, where nodes can no longer communicate with each other.
#
# **The Trade-off:**
#
# Because of these inherent limitations, you can only choose two out of the three guarantees. This means there's always a trade-off to consider when designing a distributed system.
#
# Here are the possible combinations:
#
# * **CP (Consistency and Partition tolerance):**  This approach prioritizes consistency over availability. If a network partition occurs, reads might be blocked until the partition is resolved, even if other nodes are available and have updated data.
# * **AP (Availability and Partition tolerance):** This approach prioritizes availability over consistency. During a partition, the system will continue to respond to requests, but reads may return stale data from a specific node.
# * **CA (Consistency and Availability):** This approach is only possible in scenarios where network partitions are not a concern.
#
# **Choosing the Right Combination:**
#
# The best combination depends on the specific needs of your application:
#
# * **Financial transactions:** Require strong consistency to ensure accurate accounting. A CP system might be suitable.
# * **Social media platforms:** Prioritize availability to keep users engaged. An AP system might be more appropriate.
# * **Small, localized systems:** Where network partitions are unlikely, a CA system could work well.
#
# **Important Notes:**
#
# * The CAP theorem is a theoretical framework. In practice, there are many nuances and considerations that can affect the actual behavior of distributed systems.
# * There are techniques and strategies to mitigate some of the challenges posed by the CAP theorem, such as using conflict resolution algorithms or implementing eventual consistency.
#
#
# Let me know if you have any further questions or would like to explore specific aspects of the CAP theorem in more detail!

# %%
import ollama
import base64

# Read and encode image
with open("iceberg.png", "rb") as image_file:
    image_data = base64.b64encode(image_file.read()).decode('utf-8')

# Use ollama.chat with images parameter
response = ollama.chat(
    model='llava',
    messages=[
        {
            'role': 'user',
            'content': 'Describe this image in detail',
            'images': [image_data]
        }
    ]
)

print(response['message']['content'])
# Out:
#  The image is a digital graphic with a schematic representation of an iceberg model, used to illustrate the structure of a database system. It features a diagram in blue and white colors, which includes various layers representing different parts of the database architecture.
#
# At the topmost layer, labeled "iceberg catalog," there are three boxes: one titled "metadata_catalog_db" with a blue background, another labeled "current_metadata_point" with a green background, and the third with the text "manifest_files" in white on a dark blue background. The last box is connected to two other boxes by lines that indicate relationships or processes.
#
# Below this layer, there's a middle layer titled "metadata_data_layer," which includes several components: "database_files" with red and black stripes, "schema_files" in light blue, and "diffs" with white text on a dark background. These are connected by lines suggesting a hierarchical relationship between them.
#
# At the bottom of the iceberg, labeled "metadata_data_storage," there is an arrangement of boxes representing "database_files" and "schema_files." This layer is depicted in the same color scheme as the middle layer, but with different orientations and connectors to show interconnections between files.
#
# Each box is labeled with white text on a dark background, providing a clear distinction between the elements. The overall style of the image suggests it's an educational or informational graphic designed to convey the complexity of database architecture in a visual format.
